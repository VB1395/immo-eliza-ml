# %% [markdown]
# Data Cleaning

# %%
import pandas as pd
import numpy as np
df= pd.read_csv('./data/houses.csv')
display(df)
# Out:
#              id     price property_type    subproperty_type            region  \
# 0      34221000  225000.0     APARTMENT           APARTMENT          Flanders
# 1       2104000  449000.0         HOUSE               HOUSE          Flanders
# 2      34036000  335000.0     APARTMENT           APARTMENT  Brussels-Capital
# 3      58496000  501000.0         HOUSE               HOUSE          Flanders
# 4      48727000  982700.0     APARTMENT              DUPLEX          Wallonia
# ...         ...       ...           ...                 ...               ...
# 75506  30785000  210000.0     APARTMENT           APARTMENT          Wallonia
# 75507  13524000  780000.0     APARTMENT           PENTHOUSE  Brussels-Capital
# 75508  43812000  798000.0         HOUSE  MIXED_USE_BUILDING  Brussels-Capital
# 75509  49707000  575000.0         HOUSE               VILLA          Flanders
# 75510  65278000  515000.0     APARTMENT           PENTHOUSE          Flanders
#
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# price                                 0
# property_type                         0
# subproperty_type                      0
# region                                0
# province                              0
# locality                              0
# zip_code                              0
# latitude                          14098
# longitude                         14098
# construction_year                 33391
# total_area_sqm                     7615
# surface_land_sqm                  36256
# nbr_frontages                     26346
# nbr_bedrooms                          0
# equipped_kitchen                      0
# fl_furnished                          0
# fl_open_fire                          0
# fl_terrace                            0
# terrace_sqm                       13140
# fl_garden                             0
# garden_sqm                         2939
# fl_swimming_pool                      0
# ...

# %%
# Changing value for kitech to 0 or 1
# df['equipped_kitchen'].unique()
# kitchen_type=['INSTALLED', 'HYPER_EQUIPPED', 'USA_HYPER_EQUIPPED',
#        'NOT_INSTALLED', 'SEMI_EQUIPPED', 'USA_INSTALLED',
#        'USA_SEMI_EQUIPPED', 'USA_UNINSTALLED']
# df['equipped_kitchen']= df['equipped_kitchen'].apply(lambda x: 0 if x== 'MISSING' else 1 )

# %%
# combining data for other aminities 
other_amenities_col = ['fl_furnished','fl_double_glazing','fl_open_fire','fl_swimming_pool','fl_floodzone']
df['other_amenities'] = df[other_amenities_col].sum(axis=1)
#df['other_amenities'] = df['other_amenities'].apply(lambda x: 1 if x else 0)
display(df)
# Out:
#              id     price property_type    subproperty_type            region  \
# 0      34221000  225000.0     APARTMENT           APARTMENT          Flanders
# 1       2104000  449000.0         HOUSE               HOUSE          Flanders
# 2      34036000  335000.0     APARTMENT           APARTMENT  Brussels-Capital
# 3      58496000  501000.0         HOUSE               HOUSE          Flanders
# 4      48727000  982700.0     APARTMENT              DUPLEX          Wallonia
# ...         ...       ...           ...                 ...               ...
# 75506  30785000  210000.0     APARTMENT           APARTMENT          Wallonia
# 75507  13524000  780000.0     APARTMENT           PENTHOUSE  Brussels-Capital
# 75508  43812000  798000.0         HOUSE  MIXED_USE_BUILDING  Brussels-Capital
# 75509  49707000  575000.0         HOUSE               VILLA          Flanders
# 75510  65278000  515000.0     APARTMENT           PENTHOUSE          Flanders
#
# ...

# %%
#drop columns which contains hig number of null vales
df.drop(['id','nbr_frontages','cadastral_income','epc','surface_land_sqm','fl_terrace','fl_garden','fl_furnished','fl_double_glazing','fl_open_fire','fl_swimming_pool','fl_floodzone'],axis=1,inplace= True)

# %%
df = df.dropna(subset=['construction_year','latitude','longitude','primary_energy_consumption_sqm'], axis=0)
#df =df.dropna(axis=0)
display(df.isnull().sum())
# Out:
# price                                0
# property_type                        0
# subproperty_type                     0
# region                               0
# province                             0
# locality                             0
# zip_code                             0
# latitude                             0
# longitude                            0
# construction_year                    0
# total_area_sqm                    1798
# nbr_bedrooms                         0
# equipped_kitchen                     0
# terrace_sqm                       5507
# garden_sqm                        1327
# state_building                       0
# primary_energy_consumption_sqm       0
# heating_type                         0
# other_amenities                      0
# dtype: int64

# %%
df.dtypes
# Out:
# price                             float64
# property_type                      object
# subproperty_type                   object
# region                             object
# province                           object
# locality                           object
# zip_code                            int64
# latitude                          float64
# longitude                         float64
# construction_year                 float64
# total_area_sqm                    float64
# nbr_bedrooms                      float64
# equipped_kitchen                   object
# terrace_sqm                       float64
# garden_sqm                        float64
# state_building                     object
# primary_energy_consumption_sqm    float64
# heating_type                       object
# other_amenities                     int64
# dtype: object

# %%
df.nunique()
# Out:
# price                              1885
# property_type                         2
# subproperty_type                     23
# region                                3
# province                             11
# locality                             43
# zip_code                            940
# latitude                          20287
# longitude                         20292
# construction_year                   208
# total_area_sqm                      707
# nbr_bedrooms                         26
# equipped_kitchen                      9
# terrace_sqm                         177
# garden_sqm                         1009
# state_building                        7
# primary_energy_consumption_sqm     1387
# heating_type                          8
# other_amenities                       5
# dtype: int64

# %%
df.describe(include='all').T
# Out:
#                                   count unique       top   freq  \
# price                           24936.0    NaN       NaN    NaN
# property_type                     24936      2     HOUSE  13610
# subproperty_type                  24936     23     HOUSE   9996
# region                            24936      3  Flanders  17719
# province                          24936     11   Antwerp   4917
# locality                          24936     43   Antwerp   2715
# zip_code                        24936.0    NaN       NaN    NaN
# latitude                        24936.0    NaN       NaN    NaN
# longitude                       24936.0    NaN       NaN    NaN
# construction_year               24936.0    NaN       NaN    NaN
# total_area_sqm                  24936.0    NaN       NaN    NaN
# nbr_bedrooms                    24936.0    NaN       NaN    NaN
# equipped_kitchen                  24936      9   MISSING   9280
# terrace_sqm                     24936.0    NaN       NaN    NaN
# ...

# %%
df.to_csv("./data/clean_data.csv",index=False)
